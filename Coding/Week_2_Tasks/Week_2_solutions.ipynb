# %%
# Install Java and Spark (updated version)
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://archive.apache.org/dist/spark/spark-3.5.2/spark-3.5.2-bin-hadoop3.tgz
# !tar -xvf spark-3.5.2-bin-hadoop3.tgz
# !pip install -q findspark pyspark

import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.5.2-bin-hadoop3"

import findspark
findspark.init()

# Create Spark Session (updated config)
spark = SparkSession.builder \
    .appName("Retail Dataset Creation") \
    .config("spark.sql.shuffle.partitions", "4") \
    .config("spark.jars.packages", "org.apache.hadoop:hadoop-aws:3.3.4") \
    .getOrCreate()
# Out:
# spark-3.5.2-bin-hadoop3/
# spark-3.5.2-bin-hadoop3/bin/
# spark-3.5.2-bin-hadoop3/bin/sparkR2.cmd
# spark-3.5.2-bin-hadoop3/bin/sparkR
# spark-3.5.2-bin-hadoop3/bin/load-spark-env.sh
# spark-3.5.2-bin-hadoop3/bin/find-spark-home.cmd
# spark-3.5.2-bin-hadoop3/bin/pyspark2.cmd
# spark-3.5.2-bin-hadoop3/bin/spark-sql.cmd
# spark-3.5.2-bin-hadoop3/bin/spark-sql2.cmd
# spark-3.5.2-bin-hadoop3/bin/spark-submit2.cmd
# spark-3.5.2-bin-hadoop3/bin/spark-class.cmd
# spark-3.5.2-bin-hadoop3/bin/spark-submit
# spark-3.5.2-bin-hadoop3/bin/spark-shell
# spark-3.5.2-bin-hadoop3/bin/spark-sql
# spark-3.5.2-bin-hadoop3/bin/load-spark-env.cmd
# spark-3.5.2-bin-hadoop3/bin/spark-class
# spark-3.5.2-bin-hadoop3/bin/spark-shell2.cmd
# spark-3.5.2-bin-hadoop3/bin/spark-submit.cmd
# spark-3.5.2-bin-hadoop3/bin/pyspark.cmd
# spark-3.5.2-bin-hadoop3/bin/pyspark
# spark-3.5.2-bin-hadoop3/bin/sparkR.cmd
# spark-3.5.2-bin-hadoop3/bin/docker-image-tool.sh
# spark-3.5.2-bin-hadoop3/bin/run-example
# spark-3.5.2-bin-hadoop3/bin/spark-class2.cmd
# spark-3.5.2-bin-hadoop3/bin/beeline
# spark-3.5.2-bin-hadoop3/bin/spark-connect-shell
# spark-3.5.2-bin-hadoop3/bin/spark-shell.cmd
# spark-3.5.2-bin-hadoop3/bin/find-spark-home
# spark-3.5.2-bin-hadoop3/bin/beeline.cmd
# spark-3.5.2-bin-hadoop3/bin/run-example.cmd
# spark-3.5.2-bin-hadoop3/yarn/
# spark-3.5.2-bin-hadoop3/yarn/spark-3.5.2-yarn-shuffle.jar
# spark-3.5.2-bin-hadoop3/kubernetes/
# spark-3.5.2-bin-hadoop3/kubernetes/dockerfiles/
# spark-3.5.2-bin-hadoop3/kubernetes/dockerfiles/spark/
# spark-3.5.2-bin-hadoop3/kubernetes/dockerfiles/spark/bindings/
# spark-3.5.2-bin-hadoop3/kubernetes/dockerfiles/spark/bindings/python/
# spark-3.5.2-bin-hadoop3/kubernetes/dockerfiles/spark/bindings/python/Dockerfile
# spark-3.5.2-bin-hadoop3/kubernetes/dockerfiles/spark/bindings/R/
# spark-3.5.2-bin-hadoop3/kubernetes/dockerfiles/spark/bindings/R/Dockerfile
# spark-3.5.2-bin-hadoop3/kubernetes/dockerfiles/spark/entrypoint.sh
# spark-3.5.2-bin-hadoop3/kubernetes/dockerfiles/spark/Dockerfile
# spark-3.5.2-bin-hadoop3/kubernetes/dockerfiles/spark/decom.sh
# spark-3.5.2-bin-hadoop3/kubernetes/tests/
# spark-3.5.2-bin-hadoop3/kubernetes/tests/decommissioning_cleanup.py
# spark-3.5.2-bin-hadoop3/kubernetes/tests/py_container_checks.py
# spark-3.5.2-bin-hadoop3/kubernetes/tests/worker_memory_check.py
# spark-3.5.2-bin-hadoop3/kubernetes/tests/python_executable_check.py
# spark-3.5.2-bin-hadoop3/kubernetes/tests/autoscale.py
# spark-3.5.2-bin-hadoop3/kubernetes/tests/decommissioning.py
# spark-3.5.2-bin-hadoop3/kubernetes/tests/pyfiles.py
# spark-3.5.2-bin-hadoop3/data/
# spark-3.5.2-bin-hadoop3/data/artifact-tests/
# spark-3.5.2-bin-hadoop3/data/artifact-tests/junitLargeJar.jar
# spark-3.5.2-bin-hadoop3/data/artifact-tests/smallJar.jar
# spark-3.5.2-bin-hadoop3/data/artifact-tests/crc/
# spark-3.5.2-bin-hadoop3/data/artifact-tests/crc/junitLargeJar.txt
# spark-3.5.2-bin-hadoop3/data/artifact-tests/crc/README.md
# spark-3.5.2-bin-hadoop3/data/artifact-tests/crc/smallJar.txt
# spark-3.5.2-bin-hadoop3/data/streaming/
# spark-3.5.2-bin-hadoop3/data/streaming/AFINN-111.txt
# spark-3.5.2-bin-hadoop3/data/mllib/
# spark-3.5.2-bin-hadoop3/data/mllib/ridge-data/
# spark-3.5.2-bin-hadoop3/data/mllib/ridge-data/lpsa.data
# spark-3.5.2-bin-hadoop3/data/mllib/sample_lda_libsvm_data.txt
# spark-3.5.2-bin-hadoop3/data/mllib/pic_data.txt
# spark-3.5.2-bin-hadoop3/data/mllib/sample_isotonic_regression_libsvm_data.txt
# spark-3.5.2-bin-hadoop3/data/mllib/sample_svm_data.txt
# spark-3.5.2-bin-hadoop3/data/mllib/sample_lda_data.txt
# spark-3.5.2-bin-hadoop3/data/mllib/sample_binary_classification_data.txt
# spark-3.5.2-bin-hadoop3/data/mllib/sample_movielens_data.txt
# spark-3.5.2-bin-hadoop3/data/mllib/streaming_kmeans_data_test.txt
# spark-3.5.2-bin-hadoop3/data/mllib/sample_kmeans_data.txt
# spark-3.5.2-bin-hadoop3/data/mllib/sample_multiclass_classification_data.txt
# spark-3.5.2-bin-hadoop3/data/mllib/images/
# spark-3.5.2-bin-hadoop3/data/mllib/images/origin/
# spark-3.5.2-bin-hadoop3/data/mllib/images/origin/multi-channel/
# spark-3.5.2-bin-hadoop3/data/mllib/images/origin/multi-channel/grayscale.jpg
# spark-3.5.2-bin-hadoop3/data/mllib/images/origin/multi-channel/chr30.4.184.jpg
# spark-3.5.2-bin-hadoop3/data/mllib/images/origin/multi-channel/BGRA_alpha_60.png
# spark-3.5.2-bin-hadoop3/data/mllib/images/origin/multi-channel/BGRA.png
# spark-3.5.2-bin-hadoop3/data/mllib/images/origin/license.txt
# spark-3.5.2-bin-hadoop3/data/mllib/images/origin/kittens/
# spark-3.5.2-bin-hadoop3/data/mllib/images/origin/kittens/29.5.a_b_EGDP022204.jpg
# spark-3.5.2-bin-hadoop3/data/mllib/images/origin/kittens/DP802813.jpg
# spark-3.5.2-bin-hadoop3/data/mllib/images/origin/kittens/DP153539.jpg
# spark-3.5.2-bin-hadoop3/data/mllib/images/origin/kittens/not-image.txt
# spark-3.5.2-bin-hadoop3/data/mllib/images/origin/kittens/54893.jpg
# spark-3.5.2-bin-hadoop3/data/mllib/images/license.txt
# spark-3.5.2-bin-hadoop3/data/mllib/sample_fpgrowth.txt
# spark-3.5.2-bin-hadoop3/data/mllib/kmeans_data.txt
# spark-3.5.2-bin-hadoop3/data/mllib/gmm_data.txt
# spark-3.5.2-bin-hadoop3/data/mllib/als/
# spark-3.5.2-bin-hadoop3/data/mllib/als/test.data
# spark-3.5.2-bin-hadoop3/data/mllib/als/sample_movielens_ratings.txt
# spark-3.5.2-bin-hadoop3/data/mllib/sample_linear_regression_data.txt
# spark-3.5.2-bin-hadoop3/data/mllib/sample_libsvm_data.txt
# spark-3.5.2-bin-hadoop3/data/mllib/pagerank_data.txt
# spark-3.5.2-bin-hadoop3/data/graphx/
# spark-3.5.2-bin-hadoop3/data/graphx/followers.txt
# spark-3.5.2-bin-hadoop3/data/graphx/users.txt
# spark-3.5.2-bin-hadoop3/RELEASE
# spark-3.5.2-bin-hadoop3/README.md
# spark-3.5.2-bin-hadoop3/python/
# spark-3.5.2-bin-hadoop3/python/lib/
# spark-3.5.2-bin-hadoop3/python/lib/PY4J_LICENSE.txt
# spark-3.5.2-bin-hadoop3/python/lib/py4j-0.10.9.7-src.zip
# spark-3.5.2-bin-hadoop3/python/lib/pyspark.zip
# spark-3.5.2-bin-hadoop3/python/MANIFEST.in
# spark-3.5.2-bin-hadoop3/python/README.md
# spark-3.5.2-bin-hadoop3/python/setup.cfg
# spark-3.5.2-bin-hadoop3/python/mypy.ini
# spark-3.5.2-bin-hadoop3/python/test_support/
# spark-3.5.2-bin-hadoop3/python/test_support/sql/
# spark-3.5.2-bin-hadoop3/python/test_support/sql/text-test.txt
# spark-3.5.2-bin-hadoop3/python/test_support/sql/people_array.json
# spark-3.5.2-bin-hadoop3/python/test_support/sql/streaming/
# spark-3.5.2-bin-hadoop3/python/test_support/sql/streaming/text-test.txt
# spark-3.5.2-bin-hadoop3/python/test_support/sql/people_array_utf16le.json
# spark-3.5.2-bin-hadoop3/python/test_support/sql/orc_partitioned/
# spark-3.5.2-bin-hadoop3/python/test_support/sql/orc_partitioned/b=1/
# spark-3.5.2-bin-hadoop3/python/test_support/sql/orc_partitioned/b=1/c=1/
# spark-3.5.2-bin-hadoop3/python/test_support/sql/orc_partitioned/b=1/c=1/part-r-00000-829af031-b970-49d6-ad39-30460a0be2c8.orc
# spark-3.5.2-bin-hadoop3/python/test_support/sql/orc_partitioned/b=1/c=1/.part-r-00000-829af031-b970-49d6-ad39-30460a0be2c8.orc.crc
# spark-3.5.2-bin-hadoop3/python/test_support/sql/orc_partitioned/b=0/
# spark-3.5.2-bin-hadoop3/python/test_support/sql/orc_partitioned/b=0/c=0/
# spark-3.5.2-bin-hadoop3/python/test_support/sql/orc_partitioned/b=0/c=0/part-r-00000-829af031-b970-49d6-ad39-30460a0be2c8.orc
# spark-3.5.2-bin-hadoop3/python/test_support/sql/orc_partitioned/b=0/c=0/.part-r-00000-829af031-b970-49d6-ad39-30460a0be2c8.orc.crc
# spark-3.5.2-bin-hadoop3/python/test_support/sql/orc_partitioned/_SUCCESS
# spark-3.5.2-bin-hadoop3/python/test_support/sql/people.json
# spark-3.5.2-bin-hadoop3/python/test_support/sql/ages_newlines.csv
# spark-3.5.2-bin-hadoop3/python/test_support/sql/people1.json
# spark-3.5.2-bin-hadoop3/python/test_support/SimpleHTTPServer.py
# spark-3.5.2-bin-hadoop3/python/test_support/test_pytorch_training_file.py
# spark-3.5.2-bin-hadoop3/python/test_support/userlib-0.1.zip
# spark-3.5.2-bin-hadoop3/python/test_support/userlibrary.py
# spark-3.5.2-bin-hadoop3/python/test_support/hello/
# spark-3.5.2-bin-hadoop3/python/test_support/hello/hello.txt
# spark-3.5.2-bin-hadoop3/python/test_support/hello/sub_hello/
# spark-3.5.2-bin-hadoop3/python/test_support/hello/sub_hello/sub_hello.txt
# spark-3.5.2-bin-hadoop3/python/setup.py
# spark-3.5.2-bin-hadoop3/python/run-tests.py
# spark-3.5.2-bin-hadoop3/python/pyspark/
# spark-3.5.2-bin-hadoop3/python/pyspark/find_spark_home.py
# spark-3.5.2-bin-hadoop3/python/pyspark/shell.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/group.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/types.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/conf.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/pandas/
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/pandas/types.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/pandas/map_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/pandas/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/pandas/conversion.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/pandas/functions.pyi
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/pandas/typehints.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/pandas/utils.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/pandas/group_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/pandas/functions.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/pandas/_typing/
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/pandas/_typing/__init__.pyi
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/pandas/_typing/protocols/
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/pandas/_typing/protocols/frame.pyi
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/pandas/_typing/protocols/__init__.pyi
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/pandas/_typing/protocols/series.pyi
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/pandas/serializers.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/column.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/session.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/context.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/streaming/
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/streaming/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/streaming/query.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/streaming/readwriter.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/streaming/listener.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/streaming/state.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/utils.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/readwriter.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/sql_formatter.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/catalog.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/functions.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/group.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/types.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/conf.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/_typing.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/column.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/proto/
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/proto/relations_pb2.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/proto/types_pb2.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/proto/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/proto/types_pb2.pyi
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/proto/commands_pb2.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/proto/common_pb2.pyi
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/proto/expressions_pb2.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/proto/common_pb2.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/proto/base_pb2_grpc.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/proto/base_pb2.pyi
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/proto/example_plugins_pb2.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/proto/example_plugins_pb2.pyi
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/proto/expressions_pb2.pyi
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/proto/base_pb2.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/proto/catalog_pb2.pyi
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/proto/relations_pb2.pyi
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/proto/catalog_pb2.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/proto/commands_pb2.pyi
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/session.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/conversion.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/streaming/
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/streaming/worker/
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/streaming/worker/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/streaming/worker/foreach_batch_worker.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/streaming/worker/listener_worker.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/streaming/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/streaming/query.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/streaming/readwriter.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/utils.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/readwriter.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/expressions.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/catalog.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/functions.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/protobuf/
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/protobuf/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/protobuf/functions.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/avro/
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/avro/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/avro/functions.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/client/
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/client/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/client/core.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/client/artifact.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/client/reattach.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/udtf.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/window.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/udf.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/dataframe.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/connect/plan.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/protobuf/
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/protobuf/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/protobuf/functions.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/observation.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/avro/
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/avro/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/avro/functions.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/test_pandas_sqlmetrics.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/test_conf.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/test_arrow_map.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/test_udf.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/pandas/
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/pandas/test_pandas_map.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/pandas/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/pandas/test_pandas_udf.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/pandas/test_pandas_udf_typehints_with_future_annotations.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/pandas/test_pandas_udf_grouped_agg.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/pandas/test_pandas_udf_scalar.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/pandas/test_pandas_udf_window.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/pandas/test_pandas_grouped_map.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/pandas/test_pandas_cogrouped_map.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/pandas/test_pandas_grouped_map_with_state.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/pandas/test_pandas_udf_typehints.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/test_dataframe.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/test_errors.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/test_types.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/test_catalog.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/streaming/
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/streaming/test_streaming_foreach_batch.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/streaming/test_streaming_foreach.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/streaming/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/streaming/test_streaming.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/streaming/test_streaming_listener.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/test_arrow_python_udf.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/test_readwriter.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/test_udtf.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/typing/
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/typing/test_column.yml
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/typing/test_dataframe.yml
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/typing/test_udf.yml
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/typing/test_session.yml
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/typing/test_functions.yml
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/typing/test_readwriter.yml
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/test_utils.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/test_arrow.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/test_context.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/test_udf_profiler.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/test_column.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_datasources.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_pandas_grouped_map_with_state.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_catalog.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/test_connect_basic.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_dataframe.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_errors.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_pandas_udf_window.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_pandas_map.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_pandas_udf.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_readwriter.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/streaming/
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/streaming/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/streaming/test_parity_streaming.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/streaming/test_parity_listener.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/streaming/test_parity_foreach.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/streaming/test_parity_foreach_batch.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_serde.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_arrow_map.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_pandas_udf_scalar.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/test_utils.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/test_connect_column.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_udf.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_column.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_pandas_grouped_map.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_group.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/test_connect_plan.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/test_session.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_conf.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_arrow.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_arrow_python_udf.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_pandas_cogrouped_map.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/client/
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/client/test_artifact.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/client/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/client/test_client.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_functions.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_pandas_udf_grouped_agg.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_types.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/test_connect_function.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/connect/test_parity_udtf.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/test_session.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/test_group.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/test_functions.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/test_datasources.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/tests/test_serde.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/udtf.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/window.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/udf.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/dataframe.py
# spark-3.5.2-bin-hadoop3/python/pyspark/sql/_typing.pyi
# spark-3.5.2-bin-hadoop3/python/pyspark/version.py
# spark-3.5.2-bin-hadoop3/python/pyspark/errors/
# spark-3.5.2-bin-hadoop3/python/pyspark/errors/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/errors/utils.py
# spark-3.5.2-bin-hadoop3/python/pyspark/errors/exceptions/
# spark-3.5.2-bin-hadoop3/python/pyspark/errors/exceptions/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/errors/exceptions/connect.py
# spark-3.5.2-bin-hadoop3/python/pyspark/errors/exceptions/captured.py
# spark-3.5.2-bin-hadoop3/python/pyspark/errors/exceptions/base.py
# spark-3.5.2-bin-hadoop3/python/pyspark/errors/tests/
# spark-3.5.2-bin-hadoop3/python/pyspark/errors/tests/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/errors/tests/test_errors.py
# spark-3.5.2-bin-hadoop3/python/pyspark/errors/error_classes.py
# spark-3.5.2-bin-hadoop3/python/pyspark/conf.py
# spark-3.5.2-bin-hadoop3/python/pyspark/shuffle.py
# spark-3.5.2-bin-hadoop3/python/pyspark/instrumentation_utils.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/supported_api_gen.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/categorical.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/_typing.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/series.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/spark/
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/spark/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/spark/utils.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/spark/functions.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/spark/accessors.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/typedef/
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/typedef/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/typedef/typehints.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/missing/
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/missing/series.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/missing/scalars.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/missing/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/missing/resample.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/missing/frame.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/missing/groupby.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/missing/general_functions.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/missing/common.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/missing/window.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/missing/indexes.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/namespace.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/indexing.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/numpy_compat.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/mlflow.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/resample.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/correlation.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/config.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/generic.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/frame.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/utils.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/sql_formatter.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/extensions.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/groupby.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/strings.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/indexes/
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/indexes/timedelta.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/indexes/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/indexes/category.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/indexes/numeric.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/indexes/base.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/indexes/multi.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/indexes/datetimes.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/data_type_ops/
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/data_type_ops/categorical_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/data_type_ops/boolean_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/data_type_ops/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/data_type_ops/string_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/data_type_ops/timedelta_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/data_type_ops/base.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/data_type_ops/binary_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/data_type_ops/num_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/data_type_ops/null_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/data_type_ops/datetime_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/data_type_ops/complex_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/data_type_ops/udt_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/data_type_ops/date_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/base.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/accessors.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/usage_logging/
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/usage_logging/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/usage_logging/usage_logger.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/test_ops_on_diff_frames.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/frame/
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/frame/test_spark.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/frame/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/frame/test_constructor.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/frame/test_conversion.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/frame/test_reshaping.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/frame/test_take.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/frame/test_attrs.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/frame/test_time_series.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/frame/test_truncate.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/frame/test_reindexing.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/test_expanding.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/test_generic_functions.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/test_series_string.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/test_resample.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/groupby/
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/groupby/test_stat.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/groupby/test_aggregate.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/groupby/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/groupby/test_describe.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/groupby/test_missing_data.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/groupby/test_index.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/groupby/test_apply_func.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/groupby/test_head_tail.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/groupby/test_groupby.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/groupby/test_split_apply.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/groupby/test_cumulative.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/test_series_datetime.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/test_indexing.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/test_dataframe_conversion.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/test_window.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/test_csv.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/test_typedef.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/test_ewm.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/diff_frames_ops/
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/diff_frames_ops/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/diff_frames_ops/test_index.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/diff_frames_ops/test_setitem_series.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/diff_frames_ops/test_align.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/diff_frames_ops/test_cov_corrwith.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/diff_frames_ops/test_setitem_frame.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/diff_frames_ops/test_series.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/diff_frames_ops/test_basic_slow.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/diff_frames_ops/test_dot_series.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/diff_frames_ops/test_dot_frame.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/test_frame_spark.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/test_numpy_compat.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/test_utils.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/test_ops_on_diff_frames_groupby_expanding.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/test_reshape.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/test_dataframe_spark_io.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/test_scalars.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/test_rolling.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/test_namespace.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/test_series_conversion.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/test_extension.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/test_parity_series_conversion.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/test_parity_ops_on_diff_frames_groupby.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/test_parity_series_string.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/test_parity_indexing.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/test_parity_csv.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/test_parity_typedef.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/frame/
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/frame/test_parity_conversion.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/frame/test_parity_truncate.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/frame/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/frame/test_parity_spark.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/frame/test_parity_time_series.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/frame/test_parity_take.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/frame/test_parity_reindexing.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/frame/test_parity_reshaping.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/frame/test_parity_attrs.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/frame/test_parity_constructor.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/test_parity_ops_on_diff_frames.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/test_parity_ops_on_diff_frames_groupby_rolling.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/test_parity_resample.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/test_parity_scalars.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/groupby/
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/groupby/test_parity_describe.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/groupby/test_parity_head_tail.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/groupby/test_parity_cumulative.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/groupby/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/groupby/test_parity_stat.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/groupby/test_parity_index.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/groupby/test_parity_split_apply.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/groupby/test_parity_missing_data.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/groupby/test_parity_aggregate.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/groupby/test_parity_apply_func.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/groupby/test_parity_groupby.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/test_parity_categorical.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/test_parity_series_datetime.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/test_parity_config.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/test_parity_expanding.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/test_parity_frame_spark.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/test_parity_reshape.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/test_parity_default_index.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/test_parity_utils.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/test_parity_namespace.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/diff_frames_ops/
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/diff_frames_ops/test_parity_setitem_series.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/diff_frames_ops/test_parity_cov_corrwith.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/diff_frames_ops/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/diff_frames_ops/test_parity_align.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/diff_frames_ops/test_parity_dot_frame.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/diff_frames_ops/test_parity_index.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/diff_frames_ops/test_parity_series.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/diff_frames_ops/test_parity_dot_series.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/diff_frames_ops/test_parity_setitem_frame.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/diff_frames_ops/test_parity_basic_slow.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/test_parity_generic_functions.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/test_parity_rolling.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/test_parity_dataframe_conversion.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/test_parity_repr.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/test_parity_spark_functions.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/test_parity_numpy_compat.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/test_parity_ops_on_diff_frames_groupby_expanding.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/test_parity_internal.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/computation/
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/computation/test_parity_describe.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/computation/test_parity_combine.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/computation/test_parity_cumulative.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/computation/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/computation/test_parity_corrwith.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/computation/test_parity_any_all.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/computation/test_parity_eval.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/computation/test_parity_melt.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/computation/test_parity_cov.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/computation/test_parity_missing_data.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/computation/test_parity_binary_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/computation/test_parity_compute.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/computation/test_parity_apply_func.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/computation/test_parity_pivot.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/indexes/
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/indexes/test_parity_indexing.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/indexes/test_parity_rename.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/indexes/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/indexes/test_parity_datetime.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/indexes/test_parity_category.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/indexes/test_parity_align.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/indexes/test_parity_base.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/indexes/test_parity_timedelta.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/indexes/test_parity_reindex.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/indexes/test_parity_reset_index.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/test_parity_stats.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/data_type_ops/
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/data_type_ops/test_parity_num_arithmetic.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/data_type_ops/test_parity_string_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/data_type_ops/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/data_type_ops/test_parity_complex_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/data_type_ops/test_parity_udt_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/data_type_ops/test_parity_categorical_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/data_type_ops/test_parity_num_reverse.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/data_type_ops/test_parity_datetime_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/data_type_ops/test_parity_timedelta_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/data_type_ops/test_parity_boolean_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/data_type_ops/test_parity_null_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/data_type_ops/testing_utils.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/data_type_ops/test_parity_binary_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/data_type_ops/test_parity_date_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/data_type_ops/test_parity_base.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/data_type_ops/test_parity_num_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/io/
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/io/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/io/test_parity_io.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/series/
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/series/test_parity_all_any.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/series/test_parity_conversion.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/series/test_parity_cumulative.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/series/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/series/test_parity_as_type.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/series/test_parity_stat.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/series/test_parity_index.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/series/test_parity_arg_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/series/test_parity_missing_data.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/series/test_parity_series.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/series/test_parity_sort.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/series/test_parity_compute.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/series/test_parity_as_of.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/plot/
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/plot/test_parity_frame_plot.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/plot/test_parity_frame_plot_matplotlib.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/plot/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/plot/test_parity_series_plot_matplotlib.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/plot/test_parity_frame_plot_plotly.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/plot/test_parity_series_plot.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/plot/test_parity_series_plot_plotly.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/test_parity_sql.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/test_parity_extension.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/test_parity_dataframe_spark_io.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/test_parity_window.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/test_parity_indexops_spark.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/connect/test_parity_ewm.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/test_repr.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/computation/
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/computation/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/computation/test_describe.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/computation/test_any_all.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/computation/test_missing_data.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/computation/test_binary_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/computation/test_apply_func.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/computation/test_eval.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/computation/test_combine.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/computation/test_cov.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/computation/test_compute.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/computation/test_melt.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/computation/test_corrwith.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/computation/test_pivot.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/computation/test_cumulative.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/indexes/
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/indexes/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/indexes/test_indexing.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/indexes/test_base.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/indexes/test_align.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/indexes/test_category.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/indexes/test_reindex.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/indexes/test_rename.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/indexes/test_timedelta.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/indexes/test_reset_index.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/indexes/test_datetime.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/test_internal.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_udt_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_timedelta_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_boolean_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_complex_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_binary_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_null_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_base.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_date_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_num_reverse.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/testing_utils.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_string_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_categorical_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_num_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_datetime_ops.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/data_type_ops/test_num_arithmetic.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/test_config.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/test_categorical.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/io/
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/io/__init__.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/io/test_io.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/series/
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/series/test_stat.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/series/test_all_any.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/series/test_sort.py
# spark-3.5.2-bin-hadoop3/python/pyspark/pandas/tests/series/__init__.py
# ...
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/BucketizerExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/PolynomialExpansionExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/RandomForestExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/MulticlassLogisticRegressionWithElasticNetExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/ALSExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/FPGrowthExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/LinearRegressionWithElasticNetExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/SummarizerExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/DCTExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/DecisionTreeClassificationExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/PrefixSpanExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/RFormulaExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/PowerIterationClusteringExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/LogisticRegressionExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/ModelSelectionViaTrainValidationSplitExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/VarianceThresholdSelectorExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/UnivariateFeatureSelectorExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/ChiSquareTestExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/LDAExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/EstimatorTransformerParamExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/MaxAbsScalerExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/BinarizerExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/StringIndexerExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/AFTSurvivalRegressionExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/GradientBoostedTreeClassifierExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/PCAExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/GeneralizedLinearRegressionExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/LogisticRegressionWithElasticNetExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/IndexToStringExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/BisectingKMeansExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/RandomForestClassifierExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/MinMaxScalerExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/Word2VecExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/LinearSVCExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/StopWordsRemoverExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/ElementwiseProductExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/TokenizerExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/VectorIndexerExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/BucketedRandomProjectionLSHExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/GradientBoostedTreeRegressorExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/OneHotEncoderExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/ModelSelectionViaCrossValidationExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/IsotonicRegressionExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/DeveloperApiExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/FeatureHasherExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/DecisionTreeRegressionExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/RobustScalerExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/FMClassifierExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/VectorSlicerExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/ImputerExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/OneVsRestExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/SQLTransformerExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/KMeansExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/NGramExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/ml/StandardScalerExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/LocalKMeans.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/SparkLR.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/SparkPageRank.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/BinaryClassification.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/PCAOnSourceVectorExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/DenseKMeans.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/GradientBoostingRegressionExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/MultivariateSummarizer.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/AssociationRulesExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/RankingMetricsExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/GradientBoostingClassificationExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/TallSkinnyPCA.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/LogisticRegressionWithLBFGSExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/HypothesisTestingKolmogorovSmirnovTestExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/StreamingKMeansExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/StreamingLogisticRegression.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/NaiveBayesExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/GaussianMixtureExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/RandomRDDGeneration.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/NormalizerExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/ChiSqSelectorExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/SVMWithSGDExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/CosineSimilarity.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/PCAOnRowMatrixExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/SummaryStatisticsExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/FPGrowthExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/RandomForestClassificationExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/DecisionTreeClassificationExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/PrefixSpanExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/Correlations.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/StreamingLinearRegressionExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/MovieLensALS.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/SampledRDDs.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/LatentDirichletAllocationExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/SimpleFPGrowth.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/PowerIterationClusteringExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/StreamingTestExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/HypothesisTestingExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/LDAExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/AbstractParams.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/RecommendationExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/LBFGSExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/BisectingKMeansExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/Word2VecExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/ElementwiseProductExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/GradientBoostedTreesRunner.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/SVDExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/RandomForestRegressionExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/TallSkinnySVD.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/SparseNaiveBayes.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/MultiLabelMetricsExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/MulticlassMetricsExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/IsotonicRegressionExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/PMMLModelExportExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/KernelDensityEstimationExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/DecisionTreeRegressionExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/StratifiedSamplingExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/BinaryClassificationMetricsExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/KMeansExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/TFIDFExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/StandardScalerExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/DecisionTreeRunner.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/mllib/CorrelationsExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/LocalFileLR.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/AccumulatorMetricsTest.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/HdfsTest.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/BroadcastTest.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/LocalLR.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/graphx/
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/graphx/LiveJournalPageRank.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/graphx/TriangleCountingExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/graphx/Analytics.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/graphx/ComprehensiveExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/graphx/SSSPExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/graphx/SynthBenchmark.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/graphx/AggregateMessagesExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/graphx/ConnectedComponentsExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/graphx/PageRankExample.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/MiniReadWriteTest.scala
# spark-3.5.2-bin-hadoop3/examples/src/main/scala/org/apache/spark/examples/SparkALS.scala
# spark-3.5.2-bin-hadoop3/sbin/
# spark-3.5.2-bin-hadoop3/sbin/start-worker.sh
# spark-3.5.2-bin-hadoop3/sbin/start-master.sh
# spark-3.5.2-bin-hadoop3/sbin/stop-slaves.sh
# spark-3.5.2-bin-hadoop3/sbin/stop-thriftserver.sh
# spark-3.5.2-bin-hadoop3/sbin/start-history-server.sh
# spark-3.5.2-bin-hadoop3/sbin/stop-master.sh
# spark-3.5.2-bin-hadoop3/sbin/start-mesos-shuffle-service.sh
# spark-3.5.2-bin-hadoop3/sbin/spark-config.sh
# spark-3.5.2-bin-hadoop3/sbin/start-thriftserver.sh
# spark-3.5.2-bin-hadoop3/sbin/start-slaves.sh
# spark-3.5.2-bin-hadoop3/sbin/workers.sh
# spark-3.5.2-bin-hadoop3/sbin/decommission-slave.sh
# spark-3.5.2-bin-hadoop3/sbin/stop-connect-server.sh
# spark-3.5.2-bin-hadoop3/sbin/slaves.sh
# spark-3.5.2-bin-hadoop3/sbin/stop-slave.sh
# spark-3.5.2-bin-hadoop3/sbin/decommission-worker.sh
# spark-3.5.2-bin-hadoop3/sbin/start-workers.sh
# spark-3.5.2-bin-hadoop3/sbin/stop-workers.sh
# spark-3.5.2-bin-hadoop3/sbin/stop-history-server.sh
# spark-3.5.2-bin-hadoop3/sbin/spark-daemons.sh
# spark-3.5.2-bin-hadoop3/sbin/start-mesos-dispatcher.sh
# spark-3.5.2-bin-hadoop3/sbin/start-all.sh
# spark-3.5.2-bin-hadoop3/sbin/stop-all.sh
# spark-3.5.2-bin-hadoop3/sbin/stop-mesos-shuffle-service.sh
# spark-3.5.2-bin-hadoop3/sbin/stop-mesos-dispatcher.sh
# spark-3.5.2-bin-hadoop3/sbin/stop-worker.sh
# spark-3.5.2-bin-hadoop3/sbin/start-connect-server.sh
# spark-3.5.2-bin-hadoop3/sbin/spark-daemon.sh
# spark-3.5.2-bin-hadoop3/sbin/start-slave.sh
# spark-3.5.2-bin-hadoop3/NOTICE

# %%
print(spark.version)
# Out:
# 3.5.2

# %%
# Helper functions for data generation
def random_date(start_date, end_date):
    time_between_dates = end_date - start_date
    days_between_dates = time_between_dates.days
    random_number_of_days = random.randrange(days_between_dates)
    return start_date + timedelta(days=random_number_of_days)

def generate_random_price():
    return round(random.uniform(10.0, 1000.0), 2)

def generate_random_status():
    statuses = ['PENDING', 'SHIPPED', 'DELIVERED', 'CANCELLED', 'RETURNED']
    return random.choice(statuses)

def generate_random_category():
    categories = ['ELECTRONICS', 'CLOTHING', 'HOME GOODS', 'FOOD', 'SPORTS']
    return random.choice(categories)

# Generate customer data
customer_data = []
countries = ['USA', 'Canada', 'Mexico', 'UK', 'Germany', 'France', 'Japan', 'Australia']
for cust_id in range(1, 1001):
    customer_data.append({
        'customer_id': cust_id,
        'name': f'Customer_{cust_id}',
        'email': f'customer_{cust_id}@example.com',
        'country': random.choice(countries),
        'join_date': random_date(datetime(2022, 1, 1), datetime(2024, 3, 17)),
        'is_active': random.random() > 0.1,  # 90% active customers
        'loyalty_points': random.randint(0, 10000)
    })

# Generate product data
product_data = []
for prod_id in range(1, 501):
    product_data.append({
        'product_id': prod_id,
        'name': f'Product_{prod_id}',
        'category': generate_random_category(),
        'price': generate_random_price(),
        'stock_quantity': random.randint(0, 1000),
        'description': f'Description for Product_{prod_id}',
        'created_date': random_date(datetime(2022, 1, 1), datetime(2024, 3, 17))
    })

# Generate order data
order_data = []
start_date = datetime(2023, 1, 1)
end_date = datetime(2024, 3, 17)
for order_id in range(1, 5001):
    customer_id = random.randint(1, 1000)
    order_date = random_date(start_date, end_date)
    order_data.append({
        'order_id': order_id,
        'customer_id': customer_id,
        'order_date': order_date,
        'total_amount': generate_random_price() * random.randint(1, 5),
        'status': generate_random_status(),
        'shipping_address': f"{random.randint(1, 1000)} Street_{random.randint(1, 100)}",
        'order_year': order_date.year,
        'order_month': order_date.month
    })

# Generate order items data
order_items_data = []
for order_id in range(1, 5001):
    num_items = random.randint(1, 5)
    for item in range(num_items):
        product_id = random.randint(1, 500)
        order_items_data.append({
            'order_id': order_id,
            'product_id': product_id,
            'quantity': random.randint(1, 10),
            'unit_price': generate_random_price()
        })

# Create DataFrames
customers_df = spark.createDataFrame(customer_data)
products_df = spark.createDataFrame(product_data)
orders_df = spark.createDataFrame(order_data)
order_items_df = spark.createDataFrame(order_items_data)

# Display sample data
print("Customers Sample:")
customers_df.show(5)
print("\nProducts Sample:")
products_df.show(5)
print("\nOrders Sample:")
orders_df.show(5)
print("\nOrder Items Sample:")
order_items_df.show(5)
# Out:
# Customers Sample:
# +---------+-----------+--------------------+---------+-------------------+--------------+----------+
# |  country|customer_id|               email|is_active|          join_date|loyalty_points|      name|
# +---------+-----------+--------------------+---------+-------------------+--------------+----------+
# |   France|          1|customer_1@exampl...|     true|2023-01-08 00:00:00|          8776|Customer_1|
# |       UK|          2|customer_2@exampl...|     true|2023-09-09 00:00:00|          8707|Customer_2|
# |  Germany|          3|customer_3@exampl...|     true|2022-08-27 00:00:00|          4992|Customer_3|
# |       UK|          4|customer_4@exampl...|     true|2023-07-20 00:00:00|          2002|Customer_4|
# |Australia|          5|customer_5@exampl...|     true|2022-09-14 00:00:00|          8684|Customer_5|
# +---------+-----------+--------------------+---------+-------------------+--------------+----------+
# only showing top 5 rows
#
#
# Products Sample:
# +----------+-------------------+--------------------+---------+------+----------+--------------+
# |  category|       created_date|         description|     name| price|product_id|stock_quantity|
# +----------+-------------------+--------------------+---------+------+----------+--------------+
# |      FOOD|2023-03-23 00:00:00|Description for P...|Product_1| 32.26|         1|           725|
# |      FOOD|2022-05-07 00:00:00|Description for P...|Product_2|611.09|         2|           600|
# |HOME GOODS|2022-08-27 00:00:00|Description for P...|Product_3|638.23|         3|           661|
# |    SPORTS|2023-01-07 00:00:00|Description for P...|Product_4|215.81|         4|           655|
# |  CLOTHING|2024-03-12 00:00:00|Description for P...|Product_5| 247.3|         5|            48|
# +----------+-------------------+--------------------+---------+------+----------+--------------+
# only showing top 5 rows
#
#
# Orders Sample:
# +-----------+-------------------+--------+-----------+----------+----------------+---------+------------+
# |customer_id|         order_date|order_id|order_month|order_year|shipping_address|   status|total_amount|
# +-----------+-------------------+--------+-----------+----------+----------------+---------+------------+
# |        456|2023-09-07 00:00:00|       1|          9|      2023|   566 Street_29|  PENDING|     1862.06|
# |        760|2023-02-28 00:00:00|       2|          2|      2023|   625 Street_56|DELIVERED|      353.83|
# |        511|2023-05-24 00:00:00|       3|          5|      2023|   946 Street_99|DELIVERED|       273.9|
# |        573|2023-12-30 00:00:00|       4|         12|      2023|   425 Street_18|  SHIPPED|      925.15|
# |        211|2023-02-23 00:00:00|       5|          2|      2023|   275 Street_66| RETURNED|      723.34|
# +-----------+-------------------+--------+-----------+----------+----------------+---------+------------+
# only showing top 5 rows
#
#
# Order Items Sample:
# +--------+----------+--------+----------+
# |order_id|product_id|quantity|unit_price|
# +--------+----------+--------+----------+
# |       1|       401|       3|     29.89|
# |       1|       185|       7|    270.66|
# |       1|       418|      10|    479.46|
# |       1|       191|       7|    647.11|
# |       1|       381|       3|    469.55|
# +--------+----------+--------+----------+
# only showing top 5 rows

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
import random
from datetime import datetime, timedelta, date
from pyspark.sql.functions import col, lit, concat_ws, to_timestamp, expr, explode, size, count, format_number, regexp_replace
from pyspark.sql.types import StructType, StructField, IntegerType, ArrayType, StringType

# %% [markdown]
# ### Basic Operations (Questions 1-10)

# %%
# 1. Time Series Analysis
daily_sales = order_items_df.join(orders_df, "order_id") \
    .join(products_df, "product_id") \
    .join(customers_df, "customer_id") \
    .groupBy(
        date_format("order_date", "yyyy-MM-dd").alias("date"),
        "category",
        "country"
    ) \
    .agg(sum(col("quantity") * col("unit_price")).alias("sales_amount")) \
    .withColumn("formatted_sales", format_number("sales_amount", 2)) \
    .orderBy("date")

daily_sales.show(10, truncate=False)
# Out:
# +----------+-----------+---------+------------------+---------------+
# |date      |category   |country  |sales_amount      |formatted_sales|
# +----------+-----------+---------+------------------+---------------+
# |2023-01-01|ELECTRONICS|France   |285.21            |285.21         |
# |2023-01-01|SPORTS     |Australia|5440.120000000001 |5,440.12       |
# |2023-01-01|CLOTHING   |France   |738.03            |738.03         |
# |2023-01-01|CLOTHING   |Australia|2636.9            |2,636.90       |
# |2023-01-01|ELECTRONICS|Canada   |17446.66          |17,446.66      |
# |2023-01-01|CLOTHING   |UK       |3865.0200000000004|3,865.02       |
# |2023-01-01|FOOD       |Canada   |8320.27           |8,320.27       |
# |2023-01-01|FOOD       |Japan    |3824.8500000000004|3,824.85       |
# |2023-01-01|HOME GOODS |Canada   |98.6              |98.60          |
# |2023-01-01|ELECTRONICS|UK       |19203.72          |19,203.72      |
# +----------+-----------+---------+------------------+---------------+
# only showing top 10 rows

# %%
# 2. Data Quality Check
# Create employee data with potential quality issues
employee_data = []
for emp_id in range(1, 1001):
    employee_data.append({
        'employee_id': emp_id,
        'email': f'employee_{emp_id}@example.com' if random.random() > 0.1 else 'invalid_email',
        'department_code': f'DPT{random.randint(100, 999)}' if random.random() > 0.05 else None,
        'salary': random.randint(30000, 150000) if random.random() > 0.03 else 999999
    })

employees_df = spark.createDataFrame(employee_data)

# Check data quality issues
invalid_emails = employees_df.filter(~regexp_extract('email', r'^[A-Za-z0-9+_.-]+@(.+)$', 0).isNotNull())
missing_depts = employees_df.filter(employees_df.department_code.isNull())
duplicate_ids = employees_df.groupBy('employee_id').count().filter('count > 1')
invalid_salaries = employees_df.filter(employees_df.salary > 200000)

print("Data Quality Issues:")
print(f"Invalid emails: {invalid_emails.count()}")
print(f"Missing department codes: {missing_depts.count()}")
print(f"Duplicate employee IDs: {duplicate_ids.count()}")
print(f"Invalid salaries: {invalid_salaries.count()}")
# Out:
# Data Quality Issues:
# Invalid emails: 0
# Missing department codes: 46
# Duplicate employee IDs: 0
# Invalid salaries: 28

# %%
# 3. Schema Evolution
# Create historical customer interactions with evolving schema
schema_v1 = StructType([
    StructField('customer_id', IntegerType(), True),
    StructField('interaction_date', DateType(), True),
    StructField('action', StringType(), True)
])

schema_v2 = StructType([
    StructField('customer_id', IntegerType(), True),
    StructField('interaction_date', DateType(), True),
    StructField('action', StringType(), True),
    StructField('device_type', StringType(), True),  # New field
    StructField('location', StringType(), True)      # New field
])

# Generate data with both schemas
data_v1 = [(1, date(2023, 1, 1), 'view'),
           (2, date(2023, 1, 2), 'purchase')]
data_v2 = [(3, date(2024, 1, 1), 'view', 'mobile', 'NY'),
           (4, date(2024, 1, 2), 'purchase', 'desktop', 'CA')]

df_v1 = spark.createDataFrame(data_v1, schema=schema_v1)
df_v2 = spark.createDataFrame(data_v2, schema=schema_v2)

# Combine dataframes and handle schema evolution
combined_df = df_v1.unionByName(df_v2, allowMissingColumns=True)
combined_df.show()
# Out:
# +-----------+----------------+--------+-----------+--------+
# |customer_id|interaction_date|  action|device_type|location|
# +-----------+----------------+--------+-----------+--------+
# |          1|      2023-01-01|    view|       NULL|    NULL|
# |          2|      2023-01-02|purchase|       NULL|    NULL|
# |          3|      2024-01-01|    view|     mobile|      NY|
# |          4|      2024-01-02|purchase|    desktop|      CA|
# +-----------+----------------+--------+-----------+--------+

# %%
# 4. Hierarchical Data Processing
# Create organizational structure data
org_data = [
    (1, 'CEO', None),
    (2, 'CTO', 1),
    (3, 'CFO', 1),
    (4, 'Engineering Manager', 2),
    (5, 'Dev Lead', 4),
    (6, 'Developer', 5),
    (7, 'Finance Manager', 3),
    (8, 'Accountant', 7)
]

org_df = spark.createDataFrame(org_data, ['employee_id', 'title', 'manager_id'])

# Initialize the hierarchy DataFrame with top-level employees (manager_id is NULL)
hierarchy_df = org_df.filter(col("manager_id").isNull()) \
    .withColumn("level", lit(0)) \
    .withColumn("path", col("title"))

# Iteratively process the hierarchy
for i in range(1, 10):  # Limit iterations to prevent infinite loops
    next_level_df = org_df.alias("e").join(
        hierarchy_df.alias("h"),
        col("e.manager_id") == col("h.employee_id")
    ).select(
        col("e.employee_id"),
        col("e.title"),
        col("e.manager_id"),
        (col("h.level") + 1).alias("level"),
        concat_ws(" -> ", col("h.path"), col("e.title")).alias("path")
    )

    # Append the next level to the hierarchy DataFrame
    hierarchy_df = hierarchy_df.union(next_level_df)

# Display the hierarchical structure
hierarchy_df.orderBy("level").show(truncate=False)
# Out:
# +-----------+---------------+----------+-----+-----------------------------+
# |employee_id|title          |manager_id|level|path                         |
# +-----------+---------------+----------+-----+-----------------------------+
# |1          |CEO            |NULL      |0    |CEO                          |
# |3          |CFO            |1         |1    |CEO -> CFO                   |
# |3          |CFO            |1         |1    |CEO -> CFO                   |
# |2          |CTO            |1         |1    |CEO -> CTO                   |
# |3          |CFO            |1         |1    |CEO -> CFO                   |
# |2          |CTO            |1         |1    |CEO -> CTO                   |
# |3          |CFO            |1         |1    |CEO -> CFO                   |
# |2          |CTO            |1         |1    |CEO -> CTO                   |
# |3          |CFO            |1         |1    |CEO -> CFO                   |
# |2          |CTO            |1         |1    |CEO -> CTO                   |
# |3          |CFO            |1         |1    |CEO -> CFO                   |
# |2          |CTO            |1         |1    |CEO -> CTO                   |
# |3          |CFO            |1         |1    |CEO -> CFO                   |
# |2          |CTO            |1         |1    |CEO -> CTO                   |
# |3          |CFO            |1         |1    |CEO -> CFO                   |
# |2          |CTO            |1         |1    |CEO -> CTO                   |
# |3          |CFO            |1         |1    |CEO -> CFO                   |
# |2          |CTO            |1         |1    |CEO -> CTO                   |
# |2          |CTO            |1         |1    |CEO -> CTO                   |
# |7          |Finance Manager|3         |2    |CEO -> CFO -> Finance Manager|
# +-----------+---------------+----------+-----+-----------------------------+
# only showing top 20 rows

# %%
# 5. Data Masking
# Create sensitive customer data
sensitive_data = [
    (
        '123-45-6789',
        'john.doe@example.com',
        '123-456-7890',
        '123 Main St, Apt 101, New York, NY 10001'
    ),
    (
        '987-65-4321',
        'jane.smith@example.com',
        '987-654-3210',
        '456 Oak Ave, San Francisco, CA 94105'
    )
]

schema = StructType([
    StructField('ssn', StringType(), True),
    StructField('email', StringType(), True),
    StructField('phone', StringType(), True),
    StructField('address', StringType(), True)
])

sensitive_df = spark.createDataFrame(sensitive_data, schema)

# Mask sensitive data with error handling
try:
    masked_df = sensitive_df.select(
        regexp_replace('ssn', r'(\d{3})-(\d{2})-(\d{4})', 'XXX-XX-$3').alias('masked_ssn'),
        regexp_replace('email', r'(.+)@(.+)', 'masked@$2').alias('masked_email'),
        regexp_replace('phone', r'(\d{3})-(\d{3})-(\d{4})', 'XXX-XXX-$3').alias('masked_phone'),
        regexp_replace('address', r'(.+), (.+), ([A-Z]{2}) \d{5}', 'XXXXX, XXXXX, $3 10001').alias('masked_address')
    )

    print("Original Data:")
    sensitive_df.show(truncate=False)

    print("\nMasked Data:")
    masked_df.show(truncate=False)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Original Data:
# +-----------+----------------------+------------+----------------------------------------+
# |ssn        |email                 |phone       |address                                 |
# +-----------+----------------------+------------+----------------------------------------+
# |123-45-6789|john.doe@example.com  |123-456-7890|123 Main St, Apt 101, New York, NY 10001|
# |987-65-4321|jane.smith@example.com|987-654-3210|456 Oak Ave, San Francisco, CA 94105    |
# +-----------+----------------------+------------+----------------------------------------+
#
#
# Masked Data:
# +-----------+------------------+------------+----------------------+
# |masked_ssn |masked_email      |masked_phone|masked_address        |
# +-----------+------------------+------------+----------------------+
# |XXX-XX-6789|masked@example.com|XXX-XXX-7890|XXXXX, XXXXX, NY 10001|
# |XXX-XX-4321|masked@example.com|XXX-XXX-3210|XXXXX, XXXXX, CA 10001|
# +-----------+------------------+------------+----------------------+

# %%
# 6. Event Timeline Analysis
# Create event log data
event_data = [
    (1, 'login', datetime(2024, 3, 17, 9, 0, 0)),
    (1, 'view_product', datetime(2024, 3, 17, 9, 1, 0)),
    (1, 'add_to_cart', datetime(2024, 3, 17, 9, 2, 0)),
    (1, 'checkout', datetime(2024, 3, 17, 9, 3, 0)),
    (2, 'login', datetime(2024, 3, 17, 9, 4, 0)),
    (2, 'search', datetime(2024, 3, 17, 9, 5, 0)),
    (2, 'view_product', datetime(2024, 3, 17, 9, 6, 0))
]

schema = StructType([
    StructField('user_id', IntegerType(), True),
    StructField('event_type', StringType(), True),
    StructField('timestamp', TimestampType(), True)
])

events_df = spark.createDataFrame(event_data, schema)

# Calculate time between events
window_spec = Window.partitionBy('user_id').orderBy('timestamp')
events_with_duration = events_df.withColumn(
    'time_spent',
    datediff(lead('timestamp').over(window_spec), 'timestamp')
).withColumn(
    'next_event',
    lead('event_type').over(window_spec)
)

print("Event Timeline Analysis:")
events_with_duration.show()
# Out:
# Event Timeline Analysis:
# +-------+------------+-------------------+----------+------------+
# |user_id|  event_type|          timestamp|time_spent|  next_event|
# +-------+------------+-------------------+----------+------------+
# |      1|       login|2024-03-17 09:00:00|         0|view_product|
# |      1|view_product|2024-03-17 09:01:00|         0| add_to_cart|
# |      1| add_to_cart|2024-03-17 09:02:00|         0|    checkout|
# |      1|    checkout|2024-03-17 09:03:00|      NULL|        NULL|
# |      2|       login|2024-03-17 09:04:00|         0|      search|
# |      2|      search|2024-03-17 09:05:00|         0|view_product|
# |      2|view_product|2024-03-17 09:06:00|      NULL|        NULL|
# +-------+------------+-------------------+----------+------------+

# %%
# 7. Geographic Data Processing
# Create location-based sales data
sales_data = [
    (1, 40.7128, -74.0060, 1000.0),  # New York
    (2, 34.0522, -118.2437, 2000.0), # Los Angeles
    (3, 41.8781, -87.6298, 1500.0),  # Chicago
    (4, 29.7604, -95.3698, 1200.0),  # Houston
    (5, 37.7749, -122.4194, 2500.0)   # San Francisco
]

schema = StructType([
    StructField('region_id', IntegerType(), True),
    StructField('latitude', DoubleType(), True),
    StructField('longitude', DoubleType(), True),
    StructField('sales_amount', DoubleType(), True)
])

geo_df = spark.createDataFrame(sales_data, schema)

# Calculate distances and aggregate by region
results = geo_df.select(
    'region_id',
    'sales_amount',
    round('latitude', 2).alias('latitude'),
    round('longitude', 2).alias('longitude'),
    format_number('sales_amount', 2).alias('formatted_sales')
).orderBy('sales_amount', ascending=False)

print("Geographic Sales Analysis:")
results.show()
# Out:
# Geographic Sales Analysis:
# +---------+------------+--------+---------+---------------+
# |region_id|sales_amount|latitude|longitude|formatted_sales|
# +---------+------------+--------+---------+---------------+
# |        5|      2500.0|   37.77|  -122.42|       2,500.00|
# |        2|      2000.0|   34.05|  -118.24|       2,000.00|
# |        3|      1500.0|   41.88|   -87.63|       1,500.00|
# |        4|      1200.0|   29.76|   -95.37|       1,200.00|
# |        1|      1000.0|   40.71|   -74.01|       1,000.00|
# +---------+------------+--------+---------+---------------+

# %%
# 8. Audit Trail Analysis
# Create transaction history data
transaction_data = [
    (1, 'order', 1000.0, 'created', datetime(2024, 3, 17, 9, 0, 0)),
    (1, 'order', 1100.0, 'updated', datetime(2024, 3, 17, 9, 1, 0)),
    (2, 'payment', 1000.0, 'created', datetime(2024, 3, 17, 9, 2, 0)),
    (1, 'order', 1200.0, 'updated', datetime(2024, 3, 17, 9, 3, 0)),
    (3, 'refund', 500.0, 'created', datetime(2024, 3, 17, 9, 4, 0))
]

schema = StructType([
    StructField('transaction_id', IntegerType(), True),
    StructField('type', StringType(), True),
    StructField('amount', DoubleType(), True),
    StructField('action', StringType(), True),
    StructField('timestamp', TimestampType(), True)
])

transactions_df = spark.createDataFrame(transaction_data, schema)

# Analyze transaction patterns
transaction_patterns = transactions_df.groupBy(
    'transaction_id',
    'type'
).agg(
    collect_list('action').alias('actions'),
    collect_list('timestamp').alias('timestamps'),
    collect_list('amount').alias('amounts')
).orderBy('transaction_id')

print("Transaction Patterns:")
transaction_patterns.show()
# Out:
# Transaction Patterns:
# +--------------+-------+--------------------+--------------------+--------------------+
# |transaction_id|   type|             actions|          timestamps|             amounts|
# +--------------+-------+--------------------+--------------------+--------------------+
# |             1|  order|[created, updated...|[2024-03-17 09:00...|[1000.0, 1100.0, ...|
# |             2|payment|           [created]|[2024-03-17 09:02...|            [1000.0]|
# |             3| refund|           [created]|[2024-03-17 09:04...|             [500.0]|
# +--------------+-------+--------------------+--------------------+--------------------+

# %%
# 9. Data Lineage Tracking
# Create Spark session
spark = SparkSession.builder \
    .appName("Data Lineage Tracking") \
    .getOrCreate()

# Create data transformation pipeline
lineage_data = [
    (1, 'source_data', 'raw_data.csv', '2024-03-17 09:00:00', None),
    (2, 'clean_data', 'source_data', '2024-03-17 09:30:00', 1),
    (3, 'transformed_data', 'clean_data', '2024-03-17 10:00:00', 2),
    (4, 'aggregated_data', 'transformed_data', '2024-03-17 10:30:00', 3)
]

schema = StructType([
    StructField('data_id', IntegerType(), True),
    StructField('data_name', StringType(), True),
    StructField('source', StringType(), True),
    StructField('timestamp', StringType(), True),
    StructField('parent_id', IntegerType(), True)
])

lineage_df = spark.createDataFrame(lineage_data, schema)

# Initialize the lineage DataFrame with top-level data (parent_id is None)
lineage_result = lineage_df.filter(col("parent_id").isNull()) \
    .withColumn("level", lit(0)) \
    .withColumn("path", col("data_name"))

# Iteratively process the lineage
for i in range(1, 10):  # Limit iterations to prevent infinite loops
    next_level_df = lineage_df.alias("l").join(
        lineage_result.alias("r"),
        col("l.parent_id") == col("r.data_id")
    ).select(
        col("l.data_id"),
        col("l.data_name"),
        col("l.source"),
        col("l.timestamp"),
        col("l.parent_id"),
        (col("r.level") + 1).alias("level"),
        concat_ws(" -> ", col("r.path"), col("l.data_name")).alias("path")
    )

    # Append the next level to the lineage result DataFrame
    lineage_result = lineage_result.union(next_level_df)

# Display the complete lineage tree
print("Data Lineage:")
lineage_result.orderBy("level").show(truncate=False)
# Out:
# Data Lineage:
# +-------+----------------+------------+-------------------+---------+-----+---------------------------------------------+
# |data_id|data_name       |source      |timestamp          |parent_id|level|path                                         |
# +-------+----------------+------------+-------------------+---------+-----+---------------------------------------------+
# |1      |source_data     |raw_data.csv|2024-03-17 09:00:00|NULL     |0    |source_data                                  |
# |2      |clean_data      |source_data |2024-03-17 09:30:00|1        |1    |source_data -> clean_data                    |
# |2      |clean_data      |source_data |2024-03-17 09:30:00|1        |1    |source_data -> clean_data                    |
# |2      |clean_data      |source_data |2024-03-17 09:30:00|1        |1    |source_data -> clean_data                    |
# |2      |clean_data      |source_data |2024-03-17 09:30:00|1        |1    |source_data -> clean_data                    |
# |2      |clean_data      |source_data |2024-03-17 09:30:00|1        |1    |source_data -> clean_data                    |
# |2      |clean_data      |source_data |2024-03-17 09:30:00|1        |1    |source_data -> clean_data                    |
# |2      |clean_data      |source_data |2024-03-17 09:30:00|1        |1    |source_data -> clean_data                    |
# |2      |clean_data      |source_data |2024-03-17 09:30:00|1        |1    |source_data -> clean_data                    |
# |2      |clean_data      |source_data |2024-03-17 09:30:00|1        |1    |source_data -> clean_data                    |
# |3      |transformed_data|clean_data  |2024-03-17 10:00:00|2        |2    |source_data -> clean_data -> transformed_data|
# |3      |transformed_data|clean_data  |2024-03-17 10:00:00|2        |2    |source_data -> clean_data -> transformed_data|
# |3      |transformed_data|clean_data  |2024-03-17 10:00:00|2        |2    |source_data -> clean_data -> transformed_data|
# |3      |transformed_data|clean_data  |2024-03-17 10:00:00|2        |2    |source_data -> clean_data -> transformed_data|
# |3      |transformed_data|clean_data  |2024-03-17 10:00:00|2        |2    |source_data -> clean_data -> transformed_data|
# |3      |transformed_data|clean_data  |2024-03-17 10:00:00|2        |2    |source_data -> clean_data -> transformed_data|
# |3      |transformed_data|clean_data  |2024-03-17 10:00:00|2        |2    |source_data -> clean_data -> transformed_data|
# |3      |transformed_data|clean_data  |2024-03-17 10:00:00|2        |2    |source_data -> clean_data -> transformed_data|
# |3      |transformed_data|clean_data  |2024-03-17 10:00:00|2        |2    |source_data -> clean_data -> transformed_data|
# |3      |transformed_data|clean_data  |2024-03-17 10:00:00|2        |2    |source_data -> clean_data -> transformed_data|
# +-------+----------------+------------+-------------------+---------+-----+---------------------------------------------+
# only showing top 20 rows

# %%
# 10. Compliance Reporting
# Create compliance data
compliance_data = [
    (1, 'GDPR', 'personal_data', '2024-03-17', True, '2024-03-17 09:00:00'),
    (2, 'HIPAA', 'medical_records', '2024-03-17', False, '2024-03-17 09:30:00'),
    (3, 'PCI-DSS', 'payment_data', '2024-03-17', True, '2024-03-17 10:00:00')
]

schema = StructType([
    StructField('check_id', IntegerType(), True),
    StructField('regulation', StringType(), True),
    StructField('data_type', StringType(), True),
    StructField('date', StringType(), True),
    StructField('compliant', BooleanType(), True),
    StructField('timestamp', StringType(), True)
])

compliance_df = spark.createDataFrame(compliance_data, schema)

# Generate compliance report
compliance_report = compliance_df.groupBy('regulation').agg(
    count('*').alias('total_checks'),
    sum(when(col('compliant') == True, 1).otherwise(0)).alias('compliant_checks'),
    format_number(
        sum(when(col('compliant') == True, 1).otherwise(0)) /
        count('*') * 100,
        2
    ).alias('compliance_rate')
).orderBy('regulation')

print("Compliance Report:")
compliance_report.show()
# Out:
# Compliance Report:
# +----------+------------+----------------+---------------+
# |regulation|total_checks|compliant_checks|compliance_rate|
# +----------+------------+----------------+---------------+
# |      GDPR|           1|               1|         100.00|
# |     HIPAA|           1|               0|           0.00|
# |   PCI-DSS|           1|               1|         100.00|
# +----------+------------+----------------+---------------+

# %% [markdown]
# ### Intermediate Operations (Questions 11-20)

# %%
# 1. Session Window Analysis
# Create session data
session_data = [
    (1, 'login', datetime(2024, 3, 17, 9, 0, 0)),
    (1, 'view_product', datetime(2024, 3, 17, 9, 5, 0)),
    (1, 'add_to_cart', datetime(2024, 3, 17, 9, 10, 0)),
    (2, 'login', datetime(2024, 3, 17, 9, 15, 0)),
    (2, 'search', datetime(2024, 3, 17, 9, 20, 0)),
    (2, 'view_product', datetime(2024, 3, 17, 9, 25, 0))
]

schema = StructType([
    StructField('user_id', IntegerType(), True),
    StructField('action', StringType(), True),
    StructField('timestamp', TimestampType(), True)
])

sessions_df = spark.createDataFrame(session_data, schema)

# Analyze session patterns
window_spec = Window.partitionBy('user_id').orderBy('timestamp')
session_analysis = sessions_df.withColumn(
    'session_duration',
    datediff(lead('timestamp').over(window_spec), 'timestamp')
).withColumn(
    'next_action',
    lead('action').over(window_spec)
)

print("Session Analysis:")
session_analysis.show()
# Out:
# Session Analysis:
# +-------+------------+-------------------+----------------+------------+
# |user_id|      action|          timestamp|session_duration| next_action|
# +-------+------------+-------------------+----------------+------------+
# |      1|       login|2024-03-17 09:00:00|               0|view_product|
# |      1|view_product|2024-03-17 09:05:00|               0| add_to_cart|
# |      1| add_to_cart|2024-03-17 09:10:00|            NULL|        NULL|
# |      2|       login|2024-03-17 09:15:00|               0|      search|
# |      2|      search|2024-03-17 09:20:00|               0|view_product|
# |      2|view_product|2024-03-17 09:25:00|            NULL|        NULL|
# +-------+------------+-------------------+----------------+------------+

# %%
# 2. Resource Utilization
# Create resource metrics data
resource_data = [
    (1, 'CPU', 75.5, datetime(2024, 3, 17, 9, 0, 0)),
    (1, 'Memory', 82.3, datetime(2024, 3, 17, 9, 0, 0)),
    (1, 'Disk', 65.7, datetime(2024, 3, 17, 9, 0, 0)),
    (2, 'CPU', 45.2, datetime(2024, 3, 17, 9, 5, 0)),
    (2, 'Memory', 67.8, datetime(2024, 3, 17, 9, 5, 0)),
    (2, 'Disk', 58.9, datetime(2024, 3, 17, 9, 5, 0))
]

schema = StructType([
    StructField('server_id', IntegerType(), True),
    StructField('resource_type', StringType(), True),
    StructField('usage_percent', DoubleType(), True),
    StructField('timestamp', TimestampType(), True)
])

resource_df = spark.createDataFrame(resource_data, schema)

# Analyze resource utilization
resource_analysis = resource_df.groupBy(
    'resource_type'
).agg(
    avg('usage_percent').alias('avg_usage'),
    max('usage_percent').alias('peak_usage'),
    min('usage_percent').alias('min_usage')
).orderBy('resource_type')

print("Resource Utilization Analysis:")
resource_analysis.show()
# Out:
# Resource Utilization Analysis:
# +-------------+---------+----------+---------+
# |resource_type|avg_usage|peak_usage|min_usage|
# +-------------+---------+----------+---------+
# |          CPU|    60.35|      75.5|     45.2|
# |         Disk|     62.3|      65.7|     58.9|
# |       Memory|    75.05|      82.3|     67.8|
# +-------------+---------+----------+---------+

# %%
# 3. **Pattern Recognition**
# Create Spark session
spark = SparkSession.builder \
    .appName("Pattern Recognition") \
    .getOrCreate()

# Correctly formatted transaction sequence data
sequence_data = [
    (1, ['login', 'view_product', 'add_to_cart', 'checkout']),
    (2, ['login', 'search', 'view_product', 'purchase']),
    (3, ['login', 'view_product', 'view_product', 'add_to_cart', 'checkout']),
    (4, ['login', 'search', 'search', 'view_product', 'purchase'])
]

# Define schema
schema = StructType([
    StructField('user_id', IntegerType(), True),
    StructField('sequence', ArrayType(StringType()), True)
])

# Create DataFrame
sequences_df = spark.createDataFrame(sequence_data, schema)

# Analyze patterns
pattern_analysis = sequences_df.select(
    explode(col('sequence')).alias('action'),
    size(col('sequence')).alias('sequence_length')
).groupBy('action').agg(
    count('*').alias('frequency'),
    format_number((count('*') / sequences_df.count()) * 100, 2).alias('percentage')
).orderBy('frequency', ascending=False)

print("Pattern Analysis:")
pattern_analysis.show(truncate=False)
# Out:
# Pattern Analysis:
# +------------+---------+----------+
# |action      |frequency|percentage|
# +------------+---------+----------+
# |view_product|5        |125.00    |
# |login       |4        |100.00    |
# |search      |3        |75.00     |
# |checkout    |2        |50.00     |
# |purchase    |2        |50.00     |
# |add_to_cart |2        |50.00     |
# +------------+---------+----------+

# %%
# 4. Network Analysis
# Create network data
network_data = [
    (1, 2, 0.8),  # user_id, connected_user_id, strength
    (1, 3, 0.6),
    (2, 3, 0.9),
    (2, 4, 0.7),
    (3, 4, 0.5)
]

schema = StructType([
    StructField('user_id', IntegerType(), True),
    StructField('connected_user_id', IntegerType(), True),
    StructField('strength', DoubleType(), True)
])

network_df = spark.createDataFrame(network_data, schema)

# Calculate centrality measures
def calculate_centrality(df):
    # Calculate degree centrality (number of connections)
    degree_df = df.groupBy('user_id').count().withColumnRenamed('count', 'degree')

    # Calculate strength centrality (sum of connection strengths)
    strength_df = df.groupBy('user_id').agg(sum('strength').alias('strength'))

    # Calculate betweenness centrality (number of shortest paths passing through)
    # This is a simplified version for demonstration
    betweenness_df = df.groupBy('user_id').agg(
        count(when(col('strength') > 0.7, 1)).alias('betweenness')
    )

    return degree_df.join(strength_df, 'user_id').join(betweenness_df, 'user_id')

network_metrics = calculate_centrality(network_df)
print("Network Analysis:")
network_metrics.show()
# Out:
# Network Analysis:
# +-------+------+--------+-----------+
# |user_id|degree|strength|betweenness|
# +-------+------+--------+-----------+
# |      1|     2|     1.4|          1|
# |      2|     2|     1.6|          1|
# |      3|     1|     0.5|          0|
# +-------+------+--------+-----------+

# %%
# 5. Text Processing
# Create text data
text_data = [
    (1, "Great product! Excellent quality and fast shipping."),
    (2, "Poor customer service. Delivery was delayed."),
    (3, "Amazing product! Highly recommended!"),
    (4, "Average experience. Nothing special.")
]

schema = StructType([
    StructField('id', IntegerType(), True),
    StructField('text', StringType(), True)
])

text_df = spark.createDataFrame(text_data, schema)

# Process text data
from pyspark.ml.feature import Tokenizer, StopWordsRemover
from pyspark.ml.feature import CountVectorizer
from pyspark.ml.feature import HashingTF

# Tokenize text
tokenizer = Tokenizer(inputCol="text", outputCol="words")
tokenized_df = tokenizer.transform(text_df)

# Remove stop words
stop_words = StopWordsRemover.loadDefaultStopWords("english")
stop_words_remover = StopWordsRemover(inputCol="words", outputCol="filtered_words")
filtered_df = stop_words_remover.transform(tokenized_df)

# Calculate term frequencies
cv = CountVectorizer(inputCol="filtered_words", outputCol="features", minDF=2.0)
tf_df = cv.fit(filtered_df).transform(filtered_df)

print("Text Processing Results:")
tf_df.select("id", "filtered_words", "features").show(truncate=False)
# Out:
# Text Processing Results:
# +---+------------------------------------------------------+-------------+
# |id |filtered_words                                        |features     |
# +---+------------------------------------------------------+-------------+
# |1  |[great, product!, excellent, quality, fast, shipping.]|(1,[0],[1.0])|
# |2  |[poor, customer, service., delivery, delayed.]        |(1,[],[])    |
# |3  |[amazing, product!, highly, recommended!]             |(1,[0],[1.0])|
# |4  |[average, experience., nothing, special.]             |(1,[],[])    |
# +---+------------------------------------------------------+-------------+

# %%
# 6. Event Timeline Analysis
# Create global event data
event_data = [
    (1, "2024-03-17 09:00:00", "America/New_York"),
    (2, "2024-03-17 10:00:00", "Europe/London"),
    (3, "2024-03-17 11:00:00", "Asia/Tokyo")
]

schema = StructType([
    StructField('event_id', IntegerType(), True),
    StructField('timestamp', StringType(), True),
    StructField('timezone', StringType(), True)
])

events_df = spark.createDataFrame(event_data, schema)

# Convert timestamps to local time
events_df = events_df.withColumn(
    'local_time',
    expr("to_utc_timestamp(to_timestamp(timestamp), timezone)")
)

print("Time Zone Handling Results:")
events_df.show(truncate=False)
# Out:
# Time Zone Handling Results:
# +--------+-------------------+----------------+-------------------+
# |event_id|timestamp          |timezone        |local_time         |
# +--------+-------------------+----------------+-------------------+
# |1       |2024-03-17 09:00:00|America/New_York|2024-03-17 13:00:00|
# |2       |2024-03-17 10:00:00|Europe/London   |2024-03-17 10:00:00|
# |3       |2024-03-17 11:00:00|Asia/Tokyo      |2024-03-17 02:00:00|
# +--------+-------------------+----------------+-------------------+

# %%
# 7. Data Standardization
# Create data with different formats
data = [
    ("1,234.56", "2024-03-17", "1,000", "123.45"),
    ("2,345.78", "2024/03/18", "2,000", "234.56"),
    ("3,456.90", "2024-03-19", "3,000", "345.67")
]

schema = StructType([
    StructField('amount1', StringType(), True),
    StructField('date', StringType(), True),
    StructField('amount2', StringType(), True),
    StructField('amount3', StringType(), True)
])

df = spark.createDataFrame(data, schema)

# Standardize data formats
from pyspark.sql.functions import regexp_replace, to_date, cast

standardized_df = df.select(
    regexp_replace('amount1', ',', '').cast('double').alias('amount1'),
    to_date('date', 'yyyy-MM-dd').alias('date'),
    regexp_replace('amount2', ',', '').cast('double').alias('amount2'),
    regexp_replace('amount3', ',', '').cast('double').alias('amount3')
)

print("Data Standardization Results:")
standardized_df.show()
# Out:
# Data Standardization Results:
# +-------+----------+-------+-------+
# |amount1|      date|amount2|amount3|
# +-------+----------+-------+-------+
# |1234.56|2024-03-17| 1000.0| 123.45|
# |2345.78|      NULL| 2000.0| 234.56|
# | 3456.9|2024-03-19| 3000.0| 345.67|
# +-------+----------+-------+-------+

# %%
# 8. Cache Optimization
# Create sample data
from pyspark import StorageLevel
data = [(i, f"data_{i}") for i in range(100000)]
df = spark.createDataFrame(data, ["id", "value"])

# Different caching strategies
from pyspark.sql.functions import *

# 1. Basic caching
df.cache()
print("1. Basic caching applied")

# 2. Memory only caching
df.persist(StorageLevel.MEMORY_ONLY)
print("2. Memory only caching applied")

# 3. Memory and disk caching
df.persist(StorageLevel.MEMORY_AND_DISK)
print("3. Memory and disk caching applied")

# 4. Memory only with 2 replication
df.rdd.persist(StorageLevel.MEMORY_ONLY_2)
print("4. Memory only with 2 replication applied")
# Out:
# 1. Basic caching applied
# 2. Memory only caching applied
# 3. Memory and disk caching applied
# 4. Memory only with 2 replication applied

# %%
# 9. Query Optimization
# Create sample data
data = [(i, f"data_{i}") for i in range(100000)]
df = spark.createDataFrame(data, ["id", "value"])

# 1. Using broadcast variables for joins
small_df = spark.createDataFrame([(1, "small_data")], ["id", "value"])
broadcast_df = broadcast(small_df)
optimized_join = df.join(broadcast_df, "id")

# 2. Using predicate pushdown
filtered_df = df.filter(col("id") > 50000).select("id", "value")

# 3. Using partition pruning
df.write.partitionBy("id").parquet("partitioned_data")

# # 4. Using bucketing
df.write.bucketBy(10, "id").sortBy("id").saveAsTable("bucketed_table")

# %%
# 10. Data Validation Rules
# Create sample data
data = [
    (1, "invalid.email", 50000),
    (2, "valid@email.com", 150000),
    (3, "another.invalid", 250000),
    (4, "valid2@email.com", 30000)
]

schema = StructType([
    StructField('id', IntegerType(), True),
    StructField('email', StringType(), True),
    StructField('salary', IntegerType(), True)
])

df = spark.createDataFrame(data, schema)

# Define validation rules
from pyspark.sql.functions import *

validation_rules = {
    'email_format': lambda x: x.email.rlike(r'^[A-Za-z0-9+_.-]+@(.+)$'),
    'salary_range': lambda x: x.salary.between(30000, 150000)
}

# Apply validation rules
validation_results = df.select(
    '*',
    *[when(validation_rules[rule](df), 'valid').otherwise('invalid').alias(rule)
      for rule in validation_rules]
)

print("Validation Results:")
validation_results.show()
# Out:
# Validation Results:
# +---+----------------+------+------------+------------+
# | id|           email|salary|email_format|salary_range|
# +---+----------------+------+------------+------------+
# |  1|   invalid.email| 50000|     invalid|       valid|
# |  2| valid@email.com|150000|       valid|       valid|
# |  3| another.invalid|250000|     invalid|     invalid|
# |  4|valid2@email.com| 30000|       valid|       valid|
# +---+----------------+------+------------+------------+
